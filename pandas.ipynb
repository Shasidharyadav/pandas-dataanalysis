# %% [markdown]
# <a href="https://colab.research.google.com/github/Shasidharyadav/pandas-dataanalysis/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
data = [1,2,3,4,5]
new_data = pd.Series(data)
print(new_data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd
data = {"Names" : ["shashi" ,"Yadav", "Rodda"]  , "Value" : [1 , 2, 3] }
new_data = pd.DataFrame(data)
print(new_data)
print(new_data.loc[0])
print(pd.DataFrame(data,[7,8,9]))
# Out:
#     Names  Value
# 0  shashi      1
# 1   Yadav      2
# 2   Rodda      3
# Names    shashi
# Value         1
# Name: 0, dtype: object
#     Names  Value
# 7  shashi      1
# 8   Yadav      2
# 9   Rodda      3

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-45cf698a-e8d7-442e-a7e7-ed06e39974f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45cf698a-e8d7-442e-a7e7-ed06e39974f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('data.csv')
print(data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(data.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
(data.dropna(inplace = True))

print(data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
data.fillna(100,inplace = True)
print(data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
print(data['Pulse'])
# Out:
# 0      110
# 1      117
# 2      103
# 3      109
# 4      117
#       ...
# 164    105
# 165    110
# 166    115
# 167    120
# 168    125
# Name: Pulse, Length: 164, dtype: int64

# %%
print(data[data["Maxpulse"] == 130])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 52         60    106       130     263.0
# 64         20    110       130     131.4
# 65        180     90       130     800.4
# 67        150    107       130     816.0
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 161        45     90       130     260.4
# 162        45     95       130     270.0

# %%
print(data[data.duplicated()])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 71         60    109       153     387.6
# 113        45    100       120     225.3
# 155        60    111       151     368.5

# %%
print(data[data["Maxpulse"].isin([130,120])])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 11         60    100       120     250.7
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 25         60    100       120     250.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 52         60    106       130     263.0
# 64         20    110       130     131.4
# 65        180     90       130     800.4
# 67        150    107       130     816.0
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 84         45    100       120     225.3
# 106       180     90       120     800.3
# 107        30     90       120      86.2
# 108        90     90       120     500.3
# 113        45    100       120     225.3
# 121        45    100       120     100.7
# 142        45    100       120     250.4
# 157        60    100       120     270.4
# 159        30     80       120     240.9
# ...
